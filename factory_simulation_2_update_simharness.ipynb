# %%
include("factory_simulation_2_update.jl")

### Simulation Harness
#number of realisations
M = 150
rerun = true # rerun all simulations
output = false #produce output for simulations
if output == false
    rerun = true
end
Time_limit =350_000.0

# Define path for Parameter_set data file
parameter_path = pwd() # directory name
#read the csv file 
parameter_set = read_parameters(parameter_path*"/parameter_set.csv")
perf_times = zeros(M,1) # initialise a vector to hold performance run times of the simulation
#Initialise the DataFrame of simulated Data 
state_df =  create_state_df()
entity_df = create_entity_df()
#Generate M realisations of the simulation
i=0
Total_T1 = @elapsed begin
    for seed = 1:M
    # for the given parameters in the set of parameters 
        for parameter in eachrow(parameter_set)
            i+=1
            # define the output files        
            (file_entities,file_state) = output_file(seed, parameter,output)
            # Run the simulation based on the flag or missing data files for particular seeds and parameters
            if rerun || !(isfile(file_entities) && isfile(file_state))
               # run_factory_simulation_2(seed::Int64, Time_limit::Float64,state_df::DataFrame,entity_df::DataFrame, parameter::DataFrameRow, output::Bool, file_state::String, file_entities::String)
               perf_times[seed] = @elapsed begin
                    (state_df,entity_df) = run_factory_simulation_2(seed, Time_limit,state_df,entity_df, parameter, output, file_state, file_entities)
                   state_df = vcat(state_df)
                   entity_df = vcat(entity_df)
                end
            end
        end
        println("The run time for $(seed) realisations of sim time of $(Time_limit) is $(round(sum(perf_times),digits = 2)) secs")
        println("The average run time per simulation is $(round((sum(perf_times)/i),digits = 2)) secs")
    end   
    state_df[!,:total_orders] =  state_df.length_queue1 + state_df.length_queue2 + state_df.in_service1 + state_df.in_service2
end
println("The total run time for $(M) realisations of sim time of $(Time_limit) is $(round(sum(perf_times),digits = 2)) secs")
println("The average run time per simulation is $(round(mean(perf_times),digits = 2)) secs")
println("Total time to run the code is $(round(Total_T1,digits = 2)) secs")

#write Parameter and  M realisations State and Entity Data to CSV
filename_path = pwd()*"/data"
# make the path if it does not exist
mkpath(dir)
# output function
output_DataFrame_to_CSV(state_df, filename_path)
output_DataFrame_to_CSV(entity_df, filename_path)
# Out:
# running simulation...parameters:
# Arrival = 52.76
# machine 1mean = 25.06
# machine 2mean = 59.03
# machine 1std = 7.18
# machine 2 queuemax = 4.0
# system time : 0.0, Q1 = 0, S1 = 0, Q2 = 0, S2 = 0...
# system time : 0.0, Q1 = 0, S1 = 1, Q2 = 0, S2 = 0...
# system time : 25.76, Q1 = 0, S1 = 0, Q2 = 0, S2 = 1...
# system time : 35.61, Q1 = 0, S1 = 1, Q2 = 0, S2 = 1...
# system time : 46.2, Q1 = 0, S1 = 0, Q2 = 1, S2 = 1...
# system time : 90.24, Q1 = 0, S1 = 0, Q2 = 0, S2 = 1...
# system time : 93.43, Q1 = 0, S1 = 1, Q2 = 0, S2 = 1...
# system time : 115.93, Q1 = 0, S1 = 1, Q2 = 0, S2 = 0...
# system time : 123.34, Q1 = 0, S1 = 0, Q2 = 0, S2 = 1...
# system time : 124.83, Q1 = 0, S1 = 0, Q2 = 0, S2 = 0...
# The run time for 1 realisations of sim time of 350000.0 is 0.97 secs
# The average run time per simulation is 0.97 secs
# The run time for 2 realisations of sim time of 350000.0 is 1.14 secs
# The average run time per simulation is 0.57 secs
# The run time for 3 realisations of sim time of 350000.0 is 1.32 secs
# The average run time per simulation is 0.44 secs
# The run time for 4 realisations of sim time of 350000.0 is 1.51 secs
# The average run time per simulation is 0.38 secs
# The run time for 5 realisations of sim time of 350000.0 is 1.68 secs
# The average run time per simulation is 0.34 secs
# The run time for 6 realisations of sim time of 350000.0 is 1.87 secs
# The average run time per simulation is 0.31 secs
# The run time for 7 realisations of sim time of 350000.0 is 2.04 secs
# The average run time per simulation is 0.29 secs
# The run time for 8 realisations of sim time of 350000.0 is 2.24 secs
# The average run time per simulation is 0.28 secs
# The run time for 9 realisations of sim time of 350000.0 is 2.44 secs
# The average run time per simulation is 0.27 secs
# The run time for 10 realisations of sim time of 350000.0 is 2.63 secs
# The average run time per simulation is 0.26 secs
# The run time for 11 realisations of sim time of 350000.0 is 2.85 secs
# The average run time per simulation is 0.26 secs
# The run time for 12 realisations of sim time of 350000.0 is 3.05 secs
# The average run time per simulation is 0.25 secs
# The run time for 13 realisations of sim time of 350000.0 is 3.28 secs
# The average run time per simulation is 0.25 secs
# The run time for 14 realisations of sim time of 350000.0 is 3.5 secs
# The average run time per simulation is 0.25 secs
# The run time for 15 realisations of sim time of 350000.0 is 3.72 secs
# The average run time per simulation is 0.25 secs
# The run time for 16 realisations of sim time of 350000.0 is 4.1 secs
# The average run time per simulation is 0.26 secs
# The run time for 17 realisations of sim time of 350000.0 is 4.3 secs
# The average run time per simulation is 0.25 secs
# The run time for 18 realisations of sim time of 350000.0 is 4.51 secs
# The average run time per simulation is 0.25 secs
# The run time for 19 realisations of sim time of 350000.0 is 4.75 secs
# The average run time per simulation is 0.25 secs
# The run time for 20 realisations of sim time of 350000.0 is 5.01 secs
# The average run time per simulation is 0.25 secs
# The run time for 21 realisations of sim time of 350000.0 is 5.22 secs
# The average run time per simulation is 0.25 secs
# The run time for 22 realisations of sim time of 350000.0 is 5.42 secs
# The average run time per simulation is 0.25 secs
# The run time for 23 realisations of sim time of 350000.0 is 5.66 secs
# The average run time per simulation is 0.25 secs
# The run time for 24 realisations of sim time of 350000.0 is 5.93 secs
# The average run time per simulation is 0.25 secs
# The run time for 25 realisations of sim time of 350000.0 is 6.29 secs
# The average run time per simulation is 0.25 secs
# The run time for 26 realisations of sim time of 350000.0 is 6.82 secs
# The average run time per simulation is 0.26 secs
# The run time for 27 realisations of sim time of 350000.0 is 7.12 secs
# The average run time per simulation is 0.26 secs
# The run time for 28 realisations of sim time of 350000.0 is 7.35 secs
# The average run time per simulation is 0.26 secs
# The run time for 29 realisations of sim time of 350000.0 is 7.62 secs
# The average run time per simulation is 0.26 secs
# The run time for 30 realisations of sim time of 350000.0 is 7.89 secs
# The average run time per simulation is 0.26 secs
# The run time for 31 realisations of sim time of 350000.0 is 8.17 secs
# The average run time per simulation is 0.26 secs
# The run time for 32 realisations of sim time of 350000.0 is 8.61 secs
# The average run time per simulation is 0.27 secs
# The run time for 33 realisations of sim time of 350000.0 is 9.31 secs
# The average run time per simulation is 0.28 secs
# The run time for 34 realisations of sim time of 350000.0 is 9.75 secs
# The average run time per simulation is 0.29 secs
# The run time for 35 realisations of sim time of 350000.0 is 10.38 secs
# The average run time per simulation is 0.3 secs
# The run time for 36 realisations of sim time of 350000.0 is 11.04 secs
# The average run time per simulation is 0.31 secs
# The run time for 37 realisations of sim time of 350000.0 is 11.66 secs
# The average run time per simulation is 0.32 secs
# The run time for 38 realisations of sim time of 350000.0 is 12.19 secs
# The average run time per simulation is 0.32 secs
# The run time for 39 realisations of sim time of 350000.0 is 12.7 secs
# The average run time per simulation is 0.33 secs
# The run time for 40 realisations of sim time of 350000.0 is 13.5 secs
# The average run time per simulation is 0.34 secs
# The run time for 41 realisations of sim time of 350000.0 is 13.88 secs
# The average run time per simulation is 0.34 secs
# The run time for 42 realisations of sim time of 350000.0 is 14.22 secs
# The average run time per simulation is 0.34 secs
# The run time for 43 realisations of sim time of 350000.0 is 14.58 secs
# The average run time per simulation is 0.34 secs
# The run time for 44 realisations of sim time of 350000.0 is 14.99 secs
# The average run time per simulation is 0.34 secs
# The run time for 45 realisations of sim time of 350000.0 is 15.5 secs
# The average run time per simulation is 0.34 secs
# The run time for 46 realisations of sim time of 350000.0 is 15.89 secs
# The average run time per simulation is 0.35 secs
# The run time for 47 realisations of sim time of 350000.0 is 16.28 secs
# The average run time per simulation is 0.35 secs
# The run time for 48 realisations of sim time of 350000.0 is 16.69 secs
# The average run time per simulation is 0.35 secs
# The run time for 49 realisations of sim time of 350000.0 is 17.11 secs
# The average run time per simulation is 0.35 secs
# The run time for 50 realisations of sim time of 350000.0 is 17.62 secs
# The average run time per simulation is 0.35 secs
# The run time for 51 realisations of sim time of 350000.0 is 17.99 secs
# The average run time per simulation is 0.35 secs
# The run time for 52 realisations of sim time of 350000.0 is 18.43 secs
# The average run time per simulation is 0.35 secs
# The run time for 53 realisations of sim time of 350000.0 is 19.1 secs
# The average run time per simulation is 0.36 secs
# The run time for 54 realisations of sim time of 350000.0 is 19.5 secs
# The average run time per simulation is 0.36 secs
# The run time for 55 realisations of sim time of 350000.0 is 19.95 secs
# The average run time per simulation is 0.36 secs
# The run time for 56 realisations of sim time of 350000.0 is 20.31 secs
# The average run time per simulation is 0.36 secs
# The run time for 57 realisations of sim time of 350000.0 is 20.59 secs
# The average run time per simulation is 0.36 secs
# The run time for 58 realisations of sim time of 350000.0 is 20.97 secs
# The average run time per simulation is 0.36 secs
# The run time for 59 realisations of sim time of 350000.0 is 21.36 secs
# The average run time per simulation is 0.36 secs
# The run time for 60 realisations of sim time of 350000.0 is 21.66 secs
# The average run time per simulation is 0.36 secs
# The run time for 61 realisations of sim time of 350000.0 is 21.97 secs
# The average run time per simulation is 0.36 secs
# The run time for 62 realisations of sim time of 350000.0 is 22.26 secs
# The average run time per simulation is 0.36 secs
# The run time for 63 realisations of sim time of 350000.0 is 22.66 secs
# The average run time per simulation is 0.36 secs
# The run time for 64 realisations of sim time of 350000.0 is 22.93 secs
# The average run time per simulation is 0.36 secs
# The run time for 65 realisations of sim time of 350000.0 is 23.21 secs
# The average run time per simulation is 0.36 secs
# The run time for 66 realisations of sim time of 350000.0 is 23.51 secs
# The average run time per simulation is 0.36 secs
# The run time for 67 realisations of sim time of 350000.0 is 23.87 secs
# The average run time per simulation is 0.36 secs
# The run time for 68 realisations of sim time of 350000.0 is 24.21 secs
# The average run time per simulation is 0.36 secs
# The run time for 69 realisations of sim time of 350000.0 is 24.55 secs
# The average run time per simulation is 0.36 secs
# The run time for 70 realisations of sim time of 350000.0 is 25.03 secs
# The average run time per simulation is 0.36 secs
# The run time for 71 realisations of sim time of 350000.0 is 25.42 secs
# The average run time per simulation is 0.36 secs
# The run time for 72 realisations of sim time of 350000.0 is 25.79 secs
# The average run time per simulation is 0.36 secs
# The run time for 73 realisations of sim time of 350000.0 is 26.22 secs
# The average run time per simulation is 0.36 secs
# The run time for 74 realisations of sim time of 350000.0 is 26.73 secs
# The average run time per simulation is 0.36 secs
# The run time for 75 realisations of sim time of 350000.0 is 27.15 secs
# The average run time per simulation is 0.36 secs
# The run time for 76 realisations of sim time of 350000.0 is 27.56 secs
# The average run time per simulation is 0.36 secs
# The run time for 77 realisations of sim time of 350000.0 is 28.13 secs
# The average run time per simulation is 0.37 secs
# The run time for 78 realisations of sim time of 350000.0 is 28.55 secs
# The average run time per simulation is 0.37 secs
# The run time for 79 realisations of sim time of 350000.0 is 28.97 secs
# The average run time per simulation is 0.37 secs
# The run time for 80 realisations of sim time of 350000.0 is 29.38 secs
# The average run time per simulation is 0.37 secs
# The run time for 81 realisations of sim time of 350000.0 is 29.69 secs
# The average run time per simulation is 0.37 secs
# The run time for 82 realisations of sim time of 350000.0 is 30.09 secs
# The average run time per simulation is 0.37 secs
# The run time for 83 realisations of sim time of 350000.0 is 30.56 secs
# The average run time per simulation is 0.37 secs
# The run time for 84 realisations of sim time of 350000.0 is 30.93 secs
# The average run time per simulation is 0.37 secs
# The run time for 85 realisations of sim time of 350000.0 is 31.26 secs
# The average run time per simulation is 0.37 secs
# The run time for 86 realisations of sim time of 350000.0 is 31.63 secs
# The average run time per simulation is 0.37 secs
# The run time for 87 realisations of sim time of 350000.0 is 32.09 secs
# The average run time per simulation is 0.37 secs
# The run time for 88 realisations of sim time of 350000.0 is 32.41 secs
# The average run time per simulation is 0.37 secs
# The run time for 89 realisations of sim time of 350000.0 is 32.81 secs
# The average run time per simulation is 0.37 secs
# The run time for 90 realisations of sim time of 350000.0 is 33.35 secs
# The average run time per simulation is 0.37 secs
# The run time for 91 realisations of sim time of 350000.0 is 33.75 secs
# The average run time per simulation is 0.37 secs
# The run time for 92 realisations of sim time of 350000.0 is 34.2 secs
# The average run time per simulation is 0.37 secs
# The run time for 93 realisations of sim time of 350000.0 is 34.56 secs
# The average run time per simulation is 0.37 secs
# The run time for 94 realisations of sim time of 350000.0 is 34.9 secs
# The average run time per simulation is 0.37 secs
# The run time for 95 realisations of sim time of 350000.0 is 35.34 secs
# The average run time per simulation is 0.37 secs
# The run time for 96 realisations of sim time of 350000.0 is 35.74 secs
# The average run time per simulation is 0.37 secs
# The run time for 97 realisations of sim time of 350000.0 is 36.11 secs
# The average run time per simulation is 0.37 secs
# The run time for 98 realisations of sim time of 350000.0 is 36.56 secs
# The average run time per simulation is 0.37 secs
# The run time for 99 realisations of sim time of 350000.0 is 36.94 secs
# The average run time per simulation is 0.37 secs
# The run time for 100 realisations of sim time of 350000.0 is 37.36 secs
# The average run time per simulation is 0.37 secs
# The run time for 101 realisations of sim time of 350000.0 is 37.76 secs
# The average run time per simulation is 0.37 secs
# The run time for 102 realisations of sim time of 350000.0 is 38.14 secs
# The average run time per simulation is 0.37 secs
# The run time for 103 realisations of sim time of 350000.0 is 38.64 secs
# The average run time per simulation is 0.38 secs
# The run time for 104 realisations of sim time of 350000.0 is 39.01 secs
# The average run time per simulation is 0.38 secs
# The run time for 105 realisations of sim time of 350000.0 is 39.5 secs
# The average run time per simulation is 0.38 secs
# The run time for 106 realisations of sim time of 350000.0 is 40.02 secs
# The average run time per simulation is 0.38 secs
# The run time for 107 realisations of sim time of 350000.0 is 40.53 secs
# The average run time per simulation is 0.38 secs
# The run time for 108 realisations of sim time of 350000.0 is 41.3 secs
# The average run time per simulation is 0.38 secs
# The run time for 109 realisations of sim time of 350000.0 is 41.79 secs
# The average run time per simulation is 0.38 secs
# The run time for 110 realisations of sim time of 350000.0 is 42.34 secs
# The average run time per simulation is 0.38 secs
# The run time for 111 realisations of sim time of 350000.0 is 42.84 secs
# The average run time per simulation is 0.39 secs
# The run time for 112 realisations of sim time of 350000.0 is 43.43 secs
# The average run time per simulation is 0.39 secs
# The run time for 113 realisations of sim time of 350000.0 is 43.91 secs
# The average run time per simulation is 0.39 secs
# The run time for 114 realisations of sim time of 350000.0 is 44.49 secs
# The average run time per simulation is 0.39 secs
# The run time for 115 realisations of sim time of 350000.0 is 45.07 secs
# The average run time per simulation is 0.39 secs
# The run time for 116 realisations of sim time of 350000.0 is 46.84 secs
# The average run time per simulation is 0.4 secs
# The run time for 117 realisations of sim time of 350000.0 is 47.3 secs
# The average run time per simulation is 0.4 secs
# The run time for 118 realisations of sim time of 350000.0 is 49.4 secs
# The average run time per simulation is 0.42 secs
# The run time for 119 realisations of sim time of 350000.0 is 49.92 secs
# The average run time per simulation is 0.42 secs
# The run time for 120 realisations of sim time of 350000.0 is 50.44 secs
# The average run time per simulation is 0.42 secs
# The run time for 121 realisations of sim time of 350000.0 is 51.01 secs
# The average run time per simulation is 0.42 secs
# The run time for 122 realisations of sim time of 350000.0 is 51.49 secs
# The average run time per simulation is 0.42 secs
# The run time for 123 realisations of sim time of 350000.0 is 51.97 secs
# The average run time per simulation is 0.42 secs
# The run time for 124 realisations of sim time of 350000.0 is 52.43 secs
# The average run time per simulation is 0.42 secs
# The run time for 125 realisations of sim time of 350000.0 is 52.92 secs
# The average run time per simulation is 0.42 secs
# The run time for 126 realisations of sim time of 350000.0 is 53.39 secs
# The average run time per simulation is 0.42 secs
# The run time for 127 realisations of sim time of 350000.0 is 53.9 secs
# The average run time per simulation is 0.42 secs
# The run time for 128 realisations of sim time of 350000.0 is 54.39 secs
# The average run time per simulation is 0.42 secs
# The run time for 129 realisations of sim time of 350000.0 is 54.96 secs
# The average run time per simulation is 0.43 secs
# The run time for 130 realisations of sim time of 350000.0 is 55.63 secs
# The average run time per simulation is 0.43 secs
# The run time for 131 realisations of sim time of 350000.0 is 56.3 secs
# The average run time per simulation is 0.43 secs
# The run time for 132 realisations of sim time of 350000.0 is 56.97 secs
# The average run time per simulation is 0.43 secs
# The run time for 133 realisations of sim time of 350000.0 is 57.54 secs
# The average run time per simulation is 0.43 secs
# The run time for 134 realisations of sim time of 350000.0 is 58.1 secs
# The average run time per simulation is 0.43 secs
# The run time for 135 realisations of sim time of 350000.0 is 58.81 secs
# The average run time per simulation is 0.44 secs
# The run time for 136 realisations of sim time of 350000.0 is 59.41 secs
# The average run time per simulation is 0.44 secs
# The run time for 137 realisations of sim time of 350000.0 is 60.02 secs
# The average run time per simulation is 0.44 secs
# The run time for 138 realisations of sim time of 350000.0 is 60.66 secs
# The average run time per simulation is 0.44 secs
# The run time for 139 realisations of sim time of 350000.0 is 61.42 secs
# The average run time per simulation is 0.44 secs
# The run time for 140 realisations of sim time of 350000.0 is 62.51 secs
# The average run time per simulation is 0.45 secs
# The run time for 141 realisations of sim time of 350000.0 is 63.4 secs
# The average run time per simulation is 0.45 secs
# The run time for 142 realisations of sim time of 350000.0 is 64.09 secs
# The average run time per simulation is 0.45 secs
# The run time for 143 realisations of sim time of 350000.0 is 64.63 secs
# The average run time per simulation is 0.45 secs
# The run time for 144 realisations of sim time of 350000.0 is 65.39 secs
# The average run time per simulation is 0.45 secs
# The run time for 145 realisations of sim time of 350000.0 is 66.18 secs
# The average run time per simulation is 0.46 secs
# The run time for 146 realisations of sim time of 350000.0 is 66.99 secs
# The average run time per simulation is 0.46 secs
# The run time for 147 realisations of sim time of 350000.0 is 67.88 secs
# The average run time per simulation is 0.46 secs
# The run time for 148 realisations of sim time of 350000.0 is 68.59 secs
# The average run time per simulation is 0.46 secs
# The run time for 149 realisations of sim time of 350000.0 is 69.37 secs
# The average run time per simulation is 0.47 secs
# The run time for 150 realisations of sim time of 350000.0 is 70.12 secs
# The average run time per simulation is 0.47 secs
# The total run time for 150 realisations of sim time of 350000.0 is 70.12 secs
# The average run time per simulation is 0.47 secs
# Total time to run the code is 72.44 secs
